# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# **WPS 4: Question 3(c)**
#
# Given:
# \begin{equation}
# \tilde{p} = \frac{8\tilde{T}}{3\tilde{V}-1} - \frac{3}{\tilde{V}^2},
# \end{equation}
# and
# \begin{equation}
# \frac{G}{NkT_c} = -\tilde{T}\ln(3\tilde{V}-1) + \frac{\tilde{T}}{3\tilde{V}-1} - \frac{9}{4\tilde{V}},
# \end{equation}
# we want to plot $G/NkT$ versus $p$.

# %%
def p(v, t):
    return ((8*t)/(3*v-1)) - (3/(v**2))

def g(v, t):
    return -t*np.log(3*v-1) + (t/(3*v-1)) - (9/(4*v))

# %%
V = np.linspace(0.5, 6, 1000)
T = 0.83

# %%
plt.plot(V, p(V,T))
plt.ylim(-0.4, 1.0)
plt.xlim(0, 6)
plt.xlabel(r'$\tilde{V}$', fontsize=14)
plt.ylabel(r'$\tilde{p}$', fontsize=14)
plt.show()

# %%
plt.plot(p(V,T), g(V,T))
plt.xlabel(r'$\tilde{p}$', fontsize=14)
plt.ylabel(r'$G/Nk\tilde{T}$', fontsize=14)
plt.show()
